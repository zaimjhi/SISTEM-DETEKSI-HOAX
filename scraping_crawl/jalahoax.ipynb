# %%
# url_first = 'https://tribratanews.polri.go.id/blog/none-22?search=timnas+indonesia'
# res_first = requests.get(url_first, headers=headers)
# soup_first = BeautifulSoup(res_first.text, 'lxml')

# page_numbers = []
# for a in soup_first.find_all('a'):
#     try:
#         num = int(a.text.strip())
#         page_numbers.append(num)
#     except:
#         continue

# last_page = max(page_numbers)
# print(f"🔎 Total halaman ditemukan {last_page}")

# with open('tribata.csv', 'w', newline='', encoding='utf-8') as f:
#     writer = csv.writer(f)
#     writer.writerow(['Title', 'Link', 'Time', 'Content'])

#     for page in range(1, last_page + 1):
#         print(f"\n📄 Scraping halaman {page}...")
#         url = f'https://tribratanews.polri.go.id/blog/none-22/page/{page}?search=timnas+indonesia'
#         try:
#             res = requests.get(url, headers=headers)
#             soup = BeautifulSoup(res.text, 'lxml')
#             articles = soup.find_all('article')

#             for art in articles:
#                 try:
#                     a_tag = art.find('a', class_='text-reset text-decoration-none')
#                     title = a_tag.text.strip()
#                     link = a_tag['href']
#                     time_info = art.find('span', class_='text-muted pl-2 pr-1').text.strip()
#                     content = get_article_content(link)
#                     writer.writerow([title, link, time_info, content])
#                     print(f"✅ {title}")
#                     time.sleep(1)
#                 except Exception as e:
#                     print(f"Error parsing artikel di halaman {page}: {e}")
#                     continue

#             time.sleep(1)
#         except Exception as e:
#             print(f"Gagal akses page {page}: {e}")
#             continue

import requests
from bs4 import BeautifulSoup
import csv
import time
from urllib.parse import urljoin  # We will use this to combine the base URL with relative URLs

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko)'
}

# Base URL for the site
base_url = "https://jalahoaks.jakarta.go.id"

# Function to fetch article content
def get_article_content(link):
    try:
        # Ensure the link is a full URL (combine the base URL with the relative link if necessary)
        full_url = urljoin(base_url, link)

        res = requests.get(full_url, headers=headers)
        soup = BeautifulSoup(res.text, 'lxml')

        # Find the content within the div that contains the main content
        div_content = soup.find('div', class_='text-justify')
        paragraphs = div_content.find_all('p')

        if div_content:
            return div_content.get_text(strip=True).replace('\n', ' ').replace('\r', '')
        else:
            return 'No content found'
    except Exception as e:
        print(f"Error getting content from {link}: {e}")
        return 'Error retrieving content'

# First page scraping to get the total number of pages
url_first = 'https://jalahoaks.jakarta.go.id/search?keyword=timnas'
res_first = requests.get(url_first, headers=headers)
soup_first = BeautifulSoup(res_first.text, 'lxml')

page_numbers = []
for a in soup_first.find_all('a'):
    try:
        num = int(a.text.strip())
        page_numbers.append(num)
    except ValueError:
        continue  # Skip non-numeric links

last_page = max(page_numbers) if page_numbers else 1  # Default to 1 if no page numbers are found
print(f"🔎 Total halaman ditemukan {last_page}")

# Write the scraped data to a CSV file
with open('jalahoax.csv', 'w', newline='', encoding='utf-8') as f:
    writer = csv.writer(f)
    writer.writerow(['Title', 'Link', 'Time', 'Content'])

    # Scrape each page
    for page in range(1, last_page + 1):
        print(f"\n📄 Scraping halaman {page}...")
        url = f'https://jalahoaks.jakarta.go.id/search/{page}?keyword=timnas'
        try:
            res = requests.get(url, headers=headers)
            soup = BeautifulSoup(res.text, 'lxml')
            articles = soup.find_all('li', class_='app-card card-content-border hover-border')

            for art in articles:
                try:
                    a_tag = art.find('a', class_='d-flex')
                    title = a_tag.text.strip()
                    link = a_tag['href']
                    time_info = art.find('span', class_='mr-4').text.strip()
                    content = get_article_content(link)  # Get the article content
                    writer.writerow([title, link, time_info, content])
                    print(f"✅ {title}")
                    time.sleep(1)  # Adding a delay between articles
                except Exception as e:
                    print(f"Error parsing article on page {page}: {e}")
                    continue

            time.sleep(1)  # Delay between page requests
        except Exception as e:
            print(f"Failed to access page {page}: {e}")
            continue
# Out:
# 🔎 Total halaman ditemukan 4
#
# 📄 Scraping halaman 1...
# ✅ [HOAKS] - MITCHEL BAKKER RESMI DINATURALISASI TIMNAS INDONESIA
#
#  Rabu, 05 Feb 2025
#  Berita
#  Admin
#
#
#
# Beredar sebuah unggahan di media sosial Facebook dengan narasi bahwa Mitchel Bakker telah resmi dinaturalisasi Timnas Indonesia.
# ...
# ✅ [HOAKS] - PRABOWO MEMINTA SHIN TAE-YONG KEMBALI MELATIH TIMNAS INDONESIA
#
#  Selasa, 21 Jan 2025
#  Berita
#  Admin
#
#
#                       [HOAKS] Presiden Prabowo Meminta Shin Tae-yong Kembali Melatih Timnas Indonesia
#
#
#
# Beredar informasi di Instagram yang menyatakan bahwa Presiden...
# ✅ [HOAKS] - SHIN TAE-YONG MENANGIS DI MOMEN PERPISAHAN DENGAN PEMAIN TIMNAS INDONESIA
#
#  Selasa, 14 Jan 2025
#  Berita
#  Admin
#
#
#
# Beredar video di Facebook yang diklaim memperlihatkan Shin Tae-yong menangis di momen perpisahan dengan pemain Timnas Indonesia.
# ...
# ✅ [HOAKS] - PSSI PUTUSKAN TIMNAS INDONESIA TIDAK LAGI IKUTI PIALA AFF
#
#  Kamis, 02 Jan 2025
#  Berita
#  Admin
#
#
#
# Beredar video di Facebook yang diklaim mengenai PSSI putuskan Timnas Indonesia tidak lagi ikuti Piala AFF.
#
# ...
# ✅ [HOAKS] - PRIA ARAB NGAMUK KARENA TIMNASNYA KALAH MELAWAN INDONESIA
#
#  Kamis, 28 Nov 2024
#  Berita
#  Admin
#
#
#                       DISINFORMASI
# Beredar video di YouTube yang menampilkan seseorang asal Arab Saudi marah dan memecahkan TV karena Timnas Arab Saudi dikalahkan oleh Indonesia.
# P...
# ✅ [HOAKS] - TIMNAS BAHRAIN MEMILIH DICORET DARI KUALIFIKASI PIALA DUNIA 2026 DEMI KESELAMATAN PEMAIN
#
#  Selasa, 12 Nov 2024
#  Berita
#  Admin
#
#
#                       Beredar sebuah unggahan di media sosial tentang timnas Bahrain memilih dicoret dari kualifikasi Piala Dunia 2026 demi keselamatan pemain....
# ✅ [HOAKS] - MAARTEN PAES FASIH BERBAHASA INDONESIA
#
#  Rabu, 23 Okt 2024
#  Berita
#  Admin
#
#
#
# Beredar sebuah unggahan di media sosial Facebook yang memperlihatkan kiper timnas Indonesia Maarten Paes berbicara fasih Bahasa Indonesia.
#
# ...
# ✅ [HOAKS] - LAGA TIMNAS INDONESIA VS BAHRAIN DIULANG PADA 17 OKTOBER 2024
#
#  Kamis, 17 Okt 2024
#  Berita
#  Admin
#
#
#                       Beredar sebuah video di Thread yang menginformasikan bahwa laga Indonesia vs Bahrain diulang pada 17 Oktober 2024....
#
# 📄 Scraping halaman 2...
# ✅ [HOAKS] - SHIN TAE-YONG MENANGIS DI MOMEN PERPISAHAN DENGAN PEMAIN TIMNAS INDONESIA
#
#  Selasa, 14 Jan 2025
#  Berita
#  Admin
#
#
#
# Beredar video di Facebook yang diklaim memperlihatkan Shin Tae-yong menangis di momen perpisahan dengan pemain Timnas Indonesia.
# ...
# ✅ [HOAKS] - PSSI PUTUSKAN TIMNAS INDONESIA TIDAK LAGI IKUTI PIALA AFF
#
#  Kamis, 02 Jan 2025
#  Berita
#  Admin
#
#
#
# Beredar video di Facebook yang diklaim mengenai PSSI putuskan Timnas Indonesia tidak lagi ikuti Piala AFF.
#
# ...
# ✅ [HOAKS] - PRIA ARAB NGAMUK KARENA TIMNASNYA KALAH MELAWAN INDONESIA
#
#  Kamis, 28 Nov 2024
#  Berita
#  Admin
#
#
#                       DISINFORMASI
# Beredar video di YouTube yang menampilkan seseorang asal Arab Saudi marah dan memecahkan TV karena Timnas Arab Saudi dikalahkan oleh Indonesia.
# P...
# ✅ [HOAKS] - TIMNAS BAHRAIN MEMILIH DICORET DARI KUALIFIKASI PIALA DUNIA 2026 DEMI KESELAMATAN PEMAIN
#
#  Selasa, 12 Nov 2024
#  Berita
#  Admin
#
#
#                       Beredar sebuah unggahan di media sosial tentang timnas Bahrain memilih dicoret dari kualifikasi Piala Dunia 2026 demi keselamatan pemain....
# ✅ [HOAKS] - MAARTEN PAES FASIH BERBAHASA INDONESIA
#
#  Rabu, 23 Okt 2024
#  Berita
#  Admin
#
#
#
# Beredar sebuah unggahan di media sosial Facebook yang memperlihatkan kiper timnas Indonesia Maarten Paes berbicara fasih Bahasa Indonesia.
#
# ...
# ✅ [HOAKS] - LAGA TIMNAS INDONESIA VS BAHRAIN DIULANG PADA 17 OKTOBER 2024
#
#  Kamis, 17 Okt 2024
#  Berita
#  Admin
#
#
#                       Beredar sebuah video di Thread yang menginformasikan bahwa laga Indonesia vs Bahrain diulang pada 17 Oktober 2024....
# ✅ [HOAKS] - SERAGAM TIMNAS BELANDA TERDAPAT BENDERA INDONESIA
#
#  Selasa, 02 Jul 2024
#  Berita
#  Admin
#
#
#                       [HOAKS] Seragam Timnas Belanda Terdapat Bendera Indonesia
#
#
# Beredar konten di TikTok yang menyatakan bahwa terdapat bendera Indonesia pada seragam tim ...
# ✅ [HOAKS] - VINICIUS JUNIOR MEMILIKI DARAH INDONESIA DAN INGIN BERMAIN UNTUK TIMNAS INDONESIA
#
#  Kamis, 06 Jun 2024
#  Berita
#  Admin
#
#
#                       [HOAKS] Vinicius Junior Memiliki Darah Indonesia dan Ingin Bermain untuk Timnas Indonesia
#
#
# Beredar sebuah unggahan video di media sosial Facebook dise...
#
# 📄 Scraping halaman 3...
# ✅ [HOAKS] - PSSI PUTUSKAN TIMNAS INDONESIA TIDAK LAGI IKUTI PIALA AFF
#
#  Kamis, 02 Jan 2025
#  Berita
#  Admin
#
#
#
# Beredar video di Facebook yang diklaim mengenai PSSI putuskan Timnas Indonesia tidak lagi ikuti Piala AFF.
#
# ...
# ✅ [HOAKS] - PRIA ARAB NGAMUK KARENA TIMNASNYA KALAH MELAWAN INDONESIA
#
#  Kamis, 28 Nov 2024
#  Berita
#  Admin
#
#
#                       DISINFORMASI
# Beredar video di YouTube yang menampilkan seseorang asal Arab Saudi marah dan memecahkan TV karena Timnas Arab Saudi dikalahkan oleh Indonesia.
# P...
# ✅ [HOAKS] - TIMNAS BAHRAIN MEMILIH DICORET DARI KUALIFIKASI PIALA DUNIA 2026 DEMI KESELAMATAN PEMAIN
#
#  Selasa, 12 Nov 2024
#  Berita
#  Admin
#
#
#                       Beredar sebuah unggahan di media sosial tentang timnas Bahrain memilih dicoret dari kualifikasi Piala Dunia 2026 demi keselamatan pemain....
# ✅ [HOAKS] - MAARTEN PAES FASIH BERBAHASA INDONESIA
#
#  Rabu, 23 Okt 2024
#  Berita
#  Admin
#
#
#
# Beredar sebuah unggahan di media sosial Facebook yang memperlihatkan kiper timnas Indonesia Maarten Paes berbicara fasih Bahasa Indonesia.
#
# ...
# ✅ [HOAKS] - LAGA TIMNAS INDONESIA VS BAHRAIN DIULANG PADA 17 OKTOBER 2024
#
#  Kamis, 17 Okt 2024
#  Berita
#  Admin
#
#
#                       Beredar sebuah video di Thread yang menginformasikan bahwa laga Indonesia vs Bahrain diulang pada 17 Oktober 2024....
# ✅ [HOAKS] - SERAGAM TIMNAS BELANDA TERDAPAT BENDERA INDONESIA
#
#  Selasa, 02 Jul 2024
#  Berita
#  Admin
#
#
#                       [HOAKS] Seragam Timnas Belanda Terdapat Bendera Indonesia
#
#
# Beredar konten di TikTok yang menyatakan bahwa terdapat bendera Indonesia pada seragam tim ...
# ✅ [HOAKS] - VINICIUS JUNIOR MEMILIKI DARAH INDONESIA DAN INGIN BERMAIN UNTUK TIMNAS INDONESIA
#
#  Kamis, 06 Jun 2024
#  Berita
#  Admin
#
#
#                       [HOAKS] Vinicius Junior Memiliki Darah Indonesia dan Ingin Bermain untuk Timnas Indonesia
#
#
# Beredar sebuah unggahan video di media sosial Facebook dise...
# ✅ [HOAKS] - TIMNAS SEPAK BOLA INDONESIA GANTIKAN TIMNAS ISRAEL DI OLIMPIADE 2024
#
#  Jumat, 31 Mei 2024
#  Berita
#  Admin
#
#
#                       Beredar sebuah unggahan video di media sosial Facebook dengan klaim yang menyebut bahwa Timnas Indonesia akan menggantikan Timnas Israel di Olimpiade 2024. Timn...
#
# 📄 Scraping halaman 4...
# ✅ [HOAKS] - PRIA ARAB NGAMUK KARENA TIMNASNYA KALAH MELAWAN INDONESIA
#
#  Kamis, 28 Nov 2024
#  Berita
#  Admin
#
#
#                       DISINFORMASI
# Beredar video di YouTube yang menampilkan seseorang asal Arab Saudi marah dan memecahkan TV karena Timnas Arab Saudi dikalahkan oleh Indonesia.
# P...
# ✅ [HOAKS] - TIMNAS BAHRAIN MEMILIH DICORET DARI KUALIFIKASI PIALA DUNIA 2026 DEMI KESELAMATAN PEMAIN
#
#  Selasa, 12 Nov 2024
#  Berita
#  Admin
#
#
#                       Beredar sebuah unggahan di media sosial tentang timnas Bahrain memilih dicoret dari kualifikasi Piala Dunia 2026 demi keselamatan pemain....
# ✅ [HOAKS] - MAARTEN PAES FASIH BERBAHASA INDONESIA
#
#  Rabu, 23 Okt 2024
#  Berita
#  Admin
#
#
#
# Beredar sebuah unggahan di media sosial Facebook yang memperlihatkan kiper timnas Indonesia Maarten Paes berbicara fasih Bahasa Indonesia.
#
# ...
# ✅ [HOAKS] - LAGA TIMNAS INDONESIA VS BAHRAIN DIULANG PADA 17 OKTOBER 2024
#
#  Kamis, 17 Okt 2024
#  Berita
#  Admin
#
#
#                       Beredar sebuah video di Thread yang menginformasikan bahwa laga Indonesia vs Bahrain diulang pada 17 Oktober 2024....
# ✅ [HOAKS] - SERAGAM TIMNAS BELANDA TERDAPAT BENDERA INDONESIA
#
#  Selasa, 02 Jul 2024
#  Berita
#  Admin
#
#
#                       [HOAKS] Seragam Timnas Belanda Terdapat Bendera Indonesia
#
#
# Beredar konten di TikTok yang menyatakan bahwa terdapat bendera Indonesia pada seragam tim ...
# ✅ [HOAKS] - VINICIUS JUNIOR MEMILIKI DARAH INDONESIA DAN INGIN BERMAIN UNTUK TIMNAS INDONESIA
#
#  Kamis, 06 Jun 2024
#  Berita
#  Admin
#
#
#                       [HOAKS] Vinicius Junior Memiliki Darah Indonesia dan Ingin Bermain untuk Timnas Indonesia
#
#
# Beredar sebuah unggahan video di media sosial Facebook dise...
# ✅ [HOAKS] - TIMNAS SEPAK BOLA INDONESIA GANTIKAN TIMNAS ISRAEL DI OLIMPIADE 2024
#
#  Jumat, 31 Mei 2024
#  Berita
#  Admin
#
#
#                       Beredar sebuah unggahan video di media sosial Facebook dengan klaim yang menyebut bahwa Timnas Indonesia akan menggantikan Timnas Israel di Olimpiade 2024. Timn...
# ✅ [HOAKS] - PSSI TELAH PASTIKAN TIMNAS INDONESIA AKAN BERTANDING MELAWAN PORTUGAL PADA SEPTEMBER 2024
#
#  Rabu, 22 Mei 2024
#  Berita
#  Admin
#
#
#
# Beredar video di Facebook yang mengklaim bahwa Persatuan Sepakbola Seluruh Indonesia (PSSI) telah memastikan Timnas Indonesia akan bertanding melawan Portugal...
