# %%
import requests
from bs4 import BeautifulSoup
import csv
import time

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko)'
}

def get_article_content(link):
    try:
        res = requests.get(link, headers=headers, timeout=15)
        res.raise_for_status()
        soup = BeautifulSoup(res.text, 'lxml')

        div_content = soup.find('div', class_='article-content-body__item-content')

        if div_content:
            paragraphs = div_content.find_all('p')
            content = ' '.join([p.get_text(strip=True) for p in paragraphs])
            return content
        else:
            return "Konten tidak dapat ditemukan."

    except requests.exceptions.RequestException as e:
        print(f"❌ Error saat mengakses artikel: {link} | {e}")
        return ''
    except Exception as e:
        print(f"❌ Error saat parsing konten artikel: {link} | {e}")
        return ''


url = 'https://www.liputan6.com/bola/liga-nasional'

output_filename = 'liputan6_timnas_indonesia.csv'
with open(output_filename, 'w', newline='', encoding='utf-8') as f:
    writer = csv.writer(f)
    writer.writerow(['Judul', 'Link', 'Waktu', 'Konten'])

    print(f"📄 Melakukan scraping dari halaman: {url}")

    try:
        res = requests.get(url, headers=headers, timeout=15)
        res.raise_for_status()
        soup = BeautifulSoup(res.text, 'lxml')

        articles = soup.find_all('article', class_='articles--iridescent-list--item')

        if not articles:
            print("Tidak ada artikel yang ditemukan di halaman ini.")
        else:
            print(f"🔎 Ditemukan {len(articles)} artikel. Memulai proses...")

        for art in articles:
            try:
                title_tag = art.find('h4', class_='articles--iridescent-list--text-item__title').find('a')
                link = title_tag['href']
                judul = title_tag.get_text(strip=True)

                waktu_tag = art.find('time', class_='articles--iridescent-list--text-item__time')
                waktu = waktu_tag.get_text(strip=True) if waktu_tag else 'Tidak ada waktu'

                print(f"\n📝 Mengambil konten dari: '{judul}'")
                konten = get_article_content(link)

                time.sleep(1)

                writer.writerow([judul, link, waktu, konten])
                print(f"✅ Berhasil disimpan: {judul}")

            except Exception as e:
                print(f"❌ Gagal memproses satu item artikel: {e}")
                continue

    except requests.exceptions.RequestException as e:
        print(f"❌ Gagal total mengakses URL utama: {url} | {e}")

print(f"\n🎉 Proses scraping selesai. Hasil disimpan di file '{output_filename}'.")
# Out:
# 📄 Melakukan scraping dari halaman: https://www.liputan6.com/bola/liga-nasional
# 🔎 Ditemukan 57 artikel. Memulai proses...
#
# 📝 Mengambil konten dari: 'Kapan Semifinal Piala AFF U-23?'
# ✅ Berhasil disimpan: Kapan Semifinal Piala AFF U-23?
#
# 📝 Mengambil konten dari: 'Bertemu di Semifinal AFF U-23 2025: Jadwal Indonesia vs Thailand U-23 Kapan?'
# ✅ Berhasil disimpan: Bertemu di Semifinal AFF U-23 2025: Jadwal Indonesia vs Thailand U-23 Kapan?
#
# 📝 Mengambil konten dari: 'Intip Bagan Semifinal Piala AFF U-23 2025: Ujian Berat Pertama Indonesia Lawan Thailand'
# ✅ Berhasil disimpan: Intip Bagan Semifinal Piala AFF U-23 2025: Ujian Berat Pertama Indonesia Lawan Thailand
#
# 📝 Mengambil konten dari: 'Jadwal Indonesia vs Thailand di Semifinal Piala AFF U-23 2025'
# ✅ Berhasil disimpan: Jadwal Indonesia vs Thailand di Semifinal Piala AFF U-23 2025
#
# 📝 Mengambil konten dari: 'Timnas Indonesia Bertemu Siapa di Semifinal Piala AFF U-23?'
# ✅ Berhasil disimpan: Timnas Indonesia Bertemu Siapa di Semifinal Piala AFF U-23?
#
# 📝 Mengambil konten dari: 'Jadwal Semifinal Piala AFF U-23 2025: Kapan dan Tayang di Mana?'
# ✅ Berhasil disimpan: Jadwal Semifinal Piala AFF U-23 2025: Kapan dan Tayang di Mana?
#
#
# 📝 Mengambil konten dari: 'Daftar Lengkap Pemain Persik Kediri di BRI Liga 1 2025/2026'
# ✅ Berhasil disimpan: Daftar Lengkap Pemain Persik Kediri di BRI Liga 1 2025/2026
#
# 📝 Mengambil konten dari: 'Robi Darwis, 'Anak Emas' Gerald Vanenburg di Fase Grup Piala AFF U-23 2025'
# ✅ Berhasil disimpan: Robi Darwis, 'Anak Emas' Gerald Vanenburg di Fase Grup Piala AFF U-23 2025
#
# 📝 Mengambil konten dari: 'Termasuk Eks Persija Jakarta, 3 Nama Besar yang Jarang Dimainkan Gerald Vanenburg di Fase ...'
# ✅ Berhasil disimpan: Termasuk Eks Persija Jakarta, 3 Nama Besar yang Jarang Dimainkan Gerald Vanenburg di Fase ...
#
# 📝 Mengambil konten dari: 'Erick Thohir Benarkan Patrick Kluivert Buru Pemain Timnas Indonesia U-23 untuk Kualifikasi...'
# ✅ Berhasil disimpan: Erick Thohir Benarkan Patrick Kluivert Buru Pemain Timnas Indonesia U-23 untuk Kualifikasi...
#
# 📝 Mengambil konten dari: 'Media Malaysia Sebut Harimau Muda Ompong setelah Ditahan Indonesia'
# ✅ Berhasil disimpan: Media Malaysia Sebut Harimau Muda Ompong setelah Ditahan Indonesia
#
# 📝 Mengambil konten dari: '3 Catatan dari Duel Timnas Indonesia vs Malaysia di Piala AFF U‑23 2025'
# ✅ Berhasil disimpan: 3 Catatan dari Duel Timnas Indonesia vs Malaysia di Piala AFF U‑23 2025
#
# 📝 Mengambil konten dari: 'Timnas Indonesia U‑23 Juara Grup A, tetapi Masih Ada PR Serius'
# ✅ Berhasil disimpan: Timnas Indonesia U‑23 Juara Grup A, tetapi Masih Ada PR Serius
#
# 📝 Mengambil konten dari: 'Timnas Indonesia U-23: Apa yang Harus Dijaga, Apa yang Harus Ditingkatkan?'
# ✅ Berhasil disimpan: Timnas Indonesia U-23: Apa yang Harus Dijaga, Apa yang Harus Ditingkatkan?
#
# 📝 Mengambil konten dari: 'Starting XI 'Bunglon' Gerald Vanenburg di Fase Grup Piala AFF U-23 2025: 3 Laga, Selalu Pa...'
# ✅ Berhasil disimpan: Starting XI 'Bunglon' Gerald Vanenburg di Fase Grup Piala AFF U-23 2025: 3 Laga, Selalu Pa...
#
# 📝 Mengambil konten dari: 'Piala AFF U-23: Timnas Indonesia Ditahan Malaysia, Erick Thohir Balik Soroti Lini Serang'
# ✅ Berhasil disimpan: Piala AFF U-23: Timnas Indonesia Ditahan Malaysia, Erick Thohir Balik Soroti Lini Serang
#
# 📝 Mengambil konten dari: 'Menanti Solusi untuk Lini Depan Timnas Indonesia'
# ✅ Berhasil disimpan: Menanti Solusi untuk Lini Depan Timnas Indonesia
#
# 📝 Mengambil konten dari: 'Taktik Unik Gerald Vanenburg Ketika Lawan Malaysia U-23: Tukar Peran Robi Darwis dan Toni ...'
# ✅ Berhasil disimpan: Taktik Unik Gerald Vanenburg Ketika Lawan Malaysia U-23: Tukar Peran Robi Darwis dan Toni ...
#
# 📝 Mengambil konten dari: 'Tak Terkalahkan dan Juara Grup, Tapi Banyak PR: Rekap Perjalanan Garuda Muda di Fase Grup ...'
# ✅ Berhasil disimpan: Tak Terkalahkan dan Juara Grup, Tapi Banyak PR: Rekap Perjalanan Garuda Muda di Fase Grup ...
#
# 📝 Mengambil konten dari: 'Jadwal Piala AFF U-23 Hari Ini, Selasa 22 Juli 2025'
# ✅ Berhasil disimpan: Jadwal Piala AFF U-23 Hari Ini, Selasa 22 Juli 2025
#
# 📝 Mengambil konten dari: 'Prediksi Skor Thailand U-23 vs Myanmar U-23 22 Juli 2025'
# ✅ Berhasil disimpan: Prediksi Skor Thailand U-23 vs Myanmar U-23 22 Juli 2025
#
# 📝 Mengambil konten dari: 'Prediksi Skor Vietnam U-23 vs Kamboja U-23 22 Juli 2025'
# ✅ Berhasil disimpan: Prediksi Skor Vietnam U-23 vs Kamboja U-23 22 Juli 2025
#
# 📝 Mengambil konten dari: 'Catatan-catatan Menarik dari Laga Indonesia U-23 vs Malaysia U-23: Tangan Sigap Cahya Supr...'
# ✅ Berhasil disimpan: Catatan-catatan Menarik dari Laga Indonesia U-23 vs Malaysia U-23: Tangan Sigap Cahya Supr...
#
# 📝 Mengambil konten dari: 'Pertahanan Malaysia Disiplin, Timnas U-23 Indonesia Gagal Raih Kemenangan'
# ✅ Berhasil disimpan: Pertahanan Malaysia Disiplin, Timnas U-23 Indonesia Gagal Raih Kemenangan
#
# 📝 Mengambil konten dari: 'Bawa Timnas Indonesia Lolos Semifinal Piala AFF U-23 2025, Gerald Vanenburg Siap-Siap Pant...'
# ✅ Berhasil disimpan: Bawa Timnas Indonesia Lolos Semifinal Piala AFF U-23 2025, Gerald Vanenburg Siap-Siap Pant...
#
# 📝 Mengambil konten dari: 'Nathan Tjoe-A-On Resmi Gabung Willem II, Siap Jadi Pemain Kunci di Eerste Divisie'
# ✅ Berhasil disimpan: Nathan Tjoe-A-On Resmi Gabung Willem II, Siap Jadi Pemain Kunci di Eerste Divisie
#
# 📝 Mengambil konten dari: 'Piala AFF U-23 2025: Timnas Indonesia Ditahan Malaysia, Gerald Vanenburg Akui Kehilangan A...'
# ✅ Berhasil disimpan: Piala AFF U-23 2025: Timnas Indonesia Ditahan Malaysia, Gerald Vanenburg Akui Kehilangan A...
#
# 📝 Mengambil konten dari: 'Rating Timnas Indonesia U-23 Usai Lawan Malaysia: Duo Bek Tengah Solid, Robi Darwis Tanggu...'
# ✅ Berhasil disimpan: Rating Timnas Indonesia U-23 Usai Lawan Malaysia: Duo Bek Tengah Solid, Robi Darwis Tanggu...
#
# 📝 Mengambil konten dari: 'Piala AFF U-23: Tahan Imbang Timnas Indonesia, Pelatih Malaysia Akui Sudah Antisipasi Lemp...'
# ✅ Berhasil disimpan: Piala AFF U-23: Tahan Imbang Timnas Indonesia, Pelatih Malaysia Akui Sudah Antisipasi Lemp...
#
# 📝 Mengambil konten dari: 'Irak Pantang Remehkan Timnas Indonesia di Kualifikasi Piala Dunia 2026'
# ✅ Berhasil disimpan: Irak Pantang Remehkan Timnas Indonesia di Kualifikasi Piala Dunia 2026
#
# 📝 Mengambil konten dari: 'Man of the Match Timnas Indonesia U-23 vs Timnas Malaysia U-23: Kadek Arel'
# ✅ Berhasil disimpan: Man of the Match Timnas Indonesia U-23 vs Timnas Malaysia U-23: Kadek Arel
#
# 🎉 Proses scraping selesai. Hasil disimpan di file 'liputan6_timnas_indonesia.csv'.
